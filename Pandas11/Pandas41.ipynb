# %%
import pandas as pd

print(pd.__version__)
# Out:
# 1.4.4

# %%
df =pd.read_csv(r"C:\Users\ASUS\Downloads\Visual Data\kaggle_explorations-master\belajar_matplotlib_dasar/data/titanicfull.csv")
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked
# ...

# %%
df.groupby('pclass').agg({'pclass':'count',
                         'age':['mean', 'max'],
                         'survived':'mean'})
# Out:
#        pclass        age        survived
#         count       mean   max      mean
# pclass
# 1         323  39.159930  80.0  0.619195
# 2         277  29.506705  70.0  0.429603
# 3         709  24.816367  74.0  0.255289

# %%
df.groupby('pclass').agg(n_pass=('pclass':'count'),
                         avg_age=('age', 'mean'),
                         max_age=('age','max'),
                         survival_rate=('survived,'mean'))
# Out:
#   File "C:\Users\ASUS\AppData\Local\Temp\ipykernel_17148\4272496271.py", line 1
#     df.groupby('pclass').agg(n_pass=('pclass':'count'),
#                                              ^
# SyntaxError: invalid syntax
